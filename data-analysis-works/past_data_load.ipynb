# %%
import os
from pprint import pprint
import zipfile
import pandas as pd

base_dir = "/Users/meng/MyFolder/binance-auto-trader"
workspace_dir = os.path.join(base_dir, "workspace")
data_store_dir = os.path.join(workspace_dir, "data-store")
data_loader_dir = os.path.join(workspace_dir, "binance-public-data")

# %%
print(base_dir)
print(workspace_dir)
print(data_store_dir)
print(data_loader_dir)
# Out:
# /Users/meng/MyFolder/binance-auto-trader
# /Users/meng/MyFolder/binance-auto-trader/workspace
# /Users/meng/MyFolder/binance-auto-trader/workspace/data-store
# /Users/meng/MyFolder/binance-auto-trader/workspace/binance-public-data

# %%
os.environ["STORE_DIRECTORY"]=data_store_dir
marketType = "spot"

# %% [markdown]
# # 1. Data Load

# %% [markdown]
# ## spot, klines

# %%
symbols = "BTCUSDT"
interval = "1m"
skipMonthly = 1
skipDaily = 0
startDate = "2023-09-27"
endDate = "2023-09-28"

# %%
# !python binance-public-data/python/download-kline.py \
    -t {marketType} \
    -s {symbols} \
    -i {interval} \
    -skip-monthly {skipMonthly} \
    -startDate {startDate} \
    -endDate {endDate}
# Out:
# Found 1 symbols
# [1/1] - start download daily BTCUSDT klines
#
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/klines/BTCUSDT/1m/2023-09-27_2023-09-28/BTCUSDT-1m-2023-09-27.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/klines/BTCUSDT/1m/2023-09-27_2023-09-28/BTCUSDT-1m-2023-09-28.zip
# [##################################################]

# %% [markdown]
# ## spot, aggTrades

# %%
symbols = "BTCUSDT"
skipMonthly = 1
skipDaily = 0
startDate = "2023-07-29"
endDate = "2023-09-28"

# %%
# !python binance-public-data/python/download-aggTrade.py \
    -t {marketType} \
    -s {symbols} \
    -skip-monthly {skipMonthly} \
    -startDate {startDate} \
    -endDate {endDate}
# Out:
# fetching 1 symbols from exchange
# Found 1 symbols
# [1/1] - start download daily BTCUSDT aggTrades
#
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-07-29.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-07-30.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-07-31.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-01.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-02.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-03.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-04.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-05.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-06.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-07.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-08.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-09.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-10.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-11.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-12.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-13.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-14.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-15.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-16.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-17.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-18.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-19.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-20.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-21.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-22.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-23.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-24.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-25.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-26.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-27.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-28.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-29.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-30.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-08-31.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-01.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-02.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-03.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-04.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-05.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-06.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-07.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-08.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-09.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-10.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-11.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-12.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-13.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-14.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-15.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-16.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-17.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-18.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-19.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-20.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-21.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-22.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-23.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-24.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-25.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-26.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-27.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-aggTrades-2023-09-28.zip
# [##################################################]

# %% [markdown]
# ## spot, trades

# %%
symbols = "BTCUSDT"
skipMonthly = 1
skipDaily = 0
startDate = "2023-07-29"
endDate = "2023-09-28"

# %%
# !python binance-public-data/python/download-trade.py \
    -t {marketType} \
    -s {symbols} \
    -skip-monthly {skipMonthly} \
    -startDate {startDate} \
    -endDate {endDate}
# Out:
# fetching 1 symbols from exchange
# Found 1 symbols
# [1/1] - start download daily BTCUSDT trades
#
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-07-29.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-07-30.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-07-31.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-01.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-02.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-03.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-04.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-05.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-06.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-07.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-08.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-09.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-10.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-11.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-12.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-13.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-14.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-15.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-16.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-17.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-18.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-19.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-20.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-21.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-22.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-23.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-24.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-25.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-26.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-27.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-28.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-29.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-30.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-08-31.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-01.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-02.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-03.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-04.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-05.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-06.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-07.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-08.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-09.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-10.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-11.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-12.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-13.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-14.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-15.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-16.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-17.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-18.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-19.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-20.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-21.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-22.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-23.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-24.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-25.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-26.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-27.zip
# [##################################################]
# File Download: /Users/meng/MyFolder/binance-auto-trader/workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28/BTCUSDT-trades-2023-09-28.zip
# [##################################################]

# %% [markdown]
# # 2. Data Transform

# %%
klines_path = os.path.join(base_dir, "workspace/data-store/data/spot/daily/klines/BTCUSDT/1s/2023-07-29_2023-09-28")
aggtrades_path = os.path.join(base_dir, "workspace/data-store/data/spot/daily/aggTrades/BTCUSDT/2023-07-29_2023-09-28")
trades_path = os.path.join(base_dir, "workspace/data-store/data/spot/daily/trades/BTCUSDT/2023-07-29_2023-09-28")

# %%
def read_csv_from_zip(base_path, zip_file_path):
    zf = zipfile.ZipFile(os.path.join(base_path, zip_file_path))
    df = pd.read_csv(zf.open(zip_file_path.split('.')[0]+".csv"), header=None)
    return df

def df_transform(base_path):
    zip_list = sorted(os.listdir(base_path))
    res_df = pd.DataFrame()
    for id, zip_file_path in enumerate(zip_list):
        try: # .DS_store
            df = read_csv_from_zip(base_path, zip_file_path)
            print(zip_file_path.split('.')[0]+".csv"+", shape : {}".format(df.shape), end=' ')
            if len(res_df)==0:
                res_df = df
            else:
                res_df = pd.concat([res_df, df], axis=0)
        except:
            continue
        print("res_df shape: {}".format(res_df.shape))
    res_df.reset_index(drop=True, inplace=True)
    return res_df

# %%
kl_df = df_transform(klines_path)
# Out:
# BTCUSDT-1s-2023-07-29.csv, shape : (86400, 12) res_df shape: (86400, 12)
# BTCUSDT-1s-2023-07-30.csv, shape : (86400, 12) res_df shape: (172800, 12)
# BTCUSDT-1s-2023-07-31.csv, shape : (86400, 12) res_df shape: (259200, 12)
# BTCUSDT-1s-2023-08-01.csv, shape : (86400, 12) res_df shape: (345600, 12)
# BTCUSDT-1s-2023-08-02.csv, shape : (86400, 12) res_df shape: (432000, 12)
# BTCUSDT-1s-2023-08-03.csv, shape : (86400, 12) res_df shape: (518400, 12)
# BTCUSDT-1s-2023-08-04.csv, shape : (86400, 12) res_df shape: (604800, 12)
# BTCUSDT-1s-2023-08-05.csv, shape : (86400, 12) res_df shape: (691200, 12)
# BTCUSDT-1s-2023-08-06.csv, shape : (86400, 12) res_df shape: (777600, 12)
# BTCUSDT-1s-2023-08-07.csv, shape : (86400, 12) res_df shape: (864000, 12)
# BTCUSDT-1s-2023-08-08.csv, shape : (86400, 12) res_df shape: (950400, 12)
# BTCUSDT-1s-2023-08-09.csv, shape : (86400, 12) res_df shape: (1036800, 12)
# BTCUSDT-1s-2023-08-10.csv, shape : (86400, 12) res_df shape: (1123200, 12)
# BTCUSDT-1s-2023-08-11.csv, shape : (86400, 12) res_df shape: (1209600, 12)
# BTCUSDT-1s-2023-08-12.csv, shape : (86400, 12) res_df shape: (1296000, 12)
# BTCUSDT-1s-2023-08-13.csv, shape : (86400, 12) res_df shape: (1382400, 12)
# BTCUSDT-1s-2023-08-14.csv, shape : (86400, 12) res_df shape: (1468800, 12)
# BTCUSDT-1s-2023-08-15.csv, shape : (86400, 12) res_df shape: (1555200, 12)
# BTCUSDT-1s-2023-08-16.csv, shape : (86400, 12) res_df shape: (1641600, 12)
# BTCUSDT-1s-2023-08-17.csv, shape : (86400, 12) res_df shape: (1728000, 12)
# BTCUSDT-1s-2023-08-18.csv, shape : (86400, 12) res_df shape: (1814400, 12)
# BTCUSDT-1s-2023-08-19.csv, shape : (86400, 12) res_df shape: (1900800, 12)
# BTCUSDT-1s-2023-08-20.csv, shape : (86400, 12) res_df shape: (1987200, 12)
# BTCUSDT-1s-2023-08-21.csv, shape : (86400, 12) res_df shape: (2073600, 12)
# BTCUSDT-1s-2023-08-22.csv, shape : (86400, 12) res_df shape: (2160000, 12)
# BTCUSDT-1s-2023-08-23.csv, shape : (86400, 12) res_df shape: (2246400, 12)
# BTCUSDT-1s-2023-08-24.csv, shape : (86400, 12) res_df shape: (2332800, 12)
# BTCUSDT-1s-2023-08-25.csv, shape : (86400, 12) res_df shape: (2419200, 12)
# BTCUSDT-1s-2023-08-26.csv, shape : (86400, 12) res_df shape: (2505600, 12)
# BTCUSDT-1s-2023-08-27.csv, shape : (86400, 12) res_df shape: (2592000, 12)
# BTCUSDT-1s-2023-08-28.csv, shape : (86400, 12) res_df shape: (2678400, 12)
# BTCUSDT-1s-2023-08-29.csv, shape : (86400, 12) res_df shape: (2764800, 12)
# BTCUSDT-1s-2023-08-30.csv, shape : (86400, 12) res_df shape: (2851200, 12)
# BTCUSDT-1s-2023-08-31.csv, shape : (86400, 12) res_df shape: (2937600, 12)
# BTCUSDT-1s-2023-09-01.csv, shape : (86400, 12) res_df shape: (3024000, 12)
# BTCUSDT-1s-2023-09-02.csv, shape : (86400, 12) res_df shape: (3110400, 12)
# BTCUSDT-1s-2023-09-03.csv, shape : (86400, 12) res_df shape: (3196800, 12)
# BTCUSDT-1s-2023-09-04.csv, shape : (86400, 12) res_df shape: (3283200, 12)
# BTCUSDT-1s-2023-09-05.csv, shape : (86400, 12) res_df shape: (3369600, 12)
# BTCUSDT-1s-2023-09-06.csv, shape : (86400, 12) res_df shape: (3456000, 12)
# BTCUSDT-1s-2023-09-07.csv, shape : (86400, 12) res_df shape: (3542400, 12)
# BTCUSDT-1s-2023-09-08.csv, shape : (86400, 12) res_df shape: (3628800, 12)
# BTCUSDT-1s-2023-09-09.csv, shape : (86400, 12) res_df shape: (3715200, 12)
# BTCUSDT-1s-2023-09-10.csv, shape : (86400, 12) res_df shape: (3801600, 12)
# BTCUSDT-1s-2023-09-11.csv, shape : (86400, 12) res_df shape: (3888000, 12)
# BTCUSDT-1s-2023-09-12.csv, shape : (86400, 12) res_df shape: (3974400, 12)
# BTCUSDT-1s-2023-09-13.csv, shape : (86400, 12) res_df shape: (4060800, 12)
# BTCUSDT-1s-2023-09-14.csv, shape : (86400, 12) res_df shape: (4147200, 12)
# BTCUSDT-1s-2023-09-15.csv, shape : (86400, 12) res_df shape: (4233600, 12)
# BTCUSDT-1s-2023-09-16.csv, shape : (86400, 12) res_df shape: (4320000, 12)
# BTCUSDT-1s-2023-09-17.csv, shape : (86400, 12) res_df shape: (4406400, 12)
# BTCUSDT-1s-2023-09-18.csv, shape : (86400, 12) res_df shape: (4492800, 12)
# BTCUSDT-1s-2023-09-19.csv, shape : (86400, 12) res_df shape: (4579200, 12)
# BTCUSDT-1s-2023-09-20.csv, shape : (86400, 12) res_df shape: (4665600, 12)
# BTCUSDT-1s-2023-09-21.csv, shape : (86400, 12) res_df shape: (4752000, 12)
# BTCUSDT-1s-2023-09-22.csv, shape : (86400, 12) res_df shape: (4838400, 12)
# BTCUSDT-1s-2023-09-23.csv, shape : (86400, 12) res_df shape: (4924800, 12)
# BTCUSDT-1s-2023-09-24.csv, shape : (86400, 12) res_df shape: (5011200, 12)
# BTCUSDT-1s-2023-09-25.csv, shape : (86400, 12) res_df shape: (5097600, 12)
# BTCUSDT-1s-2023-09-26.csv, shape : (86400, 12) res_df shape: (5184000, 12)
# BTCUSDT-1s-2023-09-27.csv, shape : (86400, 12) res_df shape: (5270400, 12)
# BTCUSDT-1s-2023-09-28.csv, shape : (86400, 12) res_df shape: (5356800, 12)

# %%
kl_df.to_pickle(os.path.join(data_store_dir, "BTCUSDT-230729_230928", "klines-1s.pkl"))

# %%
del kl_df

# %%
at_df = df_transform(aggtrades_path)
# Out:
# BTCUSDT-aggTrades-2023-07-29.csv, shape : (270098, 8) res_df shape: (270098, 8)
# BTCUSDT-aggTrades-2023-07-30.csv, shape : (334570, 8) res_df shape: (604668, 8)
# BTCUSDT-aggTrades-2023-07-31.csv, shape : (400283, 8) res_df shape: (1004951, 8)
# BTCUSDT-aggTrades-2023-08-01.csv, shape : (613670, 8) res_df shape: (1618621, 8)
# BTCUSDT-aggTrades-2023-08-02.csv, shape : (627482, 8) res_df shape: (2246103, 8)
# BTCUSDT-aggTrades-2023-08-03.csv, shape : (435358, 8) res_df shape: (2681461, 8)
# BTCUSDT-aggTrades-2023-08-04.csv, shape : (388889, 8) res_df shape: (3070350, 8)
# BTCUSDT-aggTrades-2023-08-05.csv, shape : (262831, 8) res_df shape: (3333181, 8)
# BTCUSDT-aggTrades-2023-08-06.csv, shape : (269225, 8) res_df shape: (3602406, 8)
# BTCUSDT-aggTrades-2023-08-07.csv, shape : (495710, 8) res_df shape: (4098116, 8)
# BTCUSDT-aggTrades-2023-08-08.csv, shape : (621988, 8) res_df shape: (4720104, 8)
# BTCUSDT-aggTrades-2023-08-09.csv, shape : (530044, 8) res_df shape: (5250148, 8)
# BTCUSDT-aggTrades-2023-08-10.csv, shape : (382071, 8) res_df shape: (5632219, 8)
# BTCUSDT-aggTrades-2023-08-11.csv, shape : (329462, 8) res_df shape: (5961681, 8)
# BTCUSDT-aggTrades-2023-08-12.csv, shape : (252321, 8) res_df shape: (6214002, 8)
# BTCUSDT-aggTrades-2023-08-13.csv, shape : (272439, 8) res_df shape: (6486441, 8)
# BTCUSDT-aggTrades-2023-08-14.csv, shape : (487440, 8) res_df shape: (6973881, 8)
# BTCUSDT-aggTrades-2023-08-15.csv, shape : (471986, 8) res_df shape: (7445867, 8)
# BTCUSDT-aggTrades-2023-08-16.csv, shape : (573279, 8) res_df shape: (8019146, 8)
# BTCUSDT-aggTrades-2023-08-17.csv, shape : (1424879, 8) res_df shape: (9444025, 8)
# BTCUSDT-aggTrades-2023-08-18.csv, shape : (939519, 8) res_df shape: (10383544, 8)
# BTCUSDT-aggTrades-2023-08-19.csv, shape : (464961, 8) res_df shape: (10848505, 8)
# BTCUSDT-aggTrades-2023-08-20.csv, shape : (343363, 8) res_df shape: (11191868, 8)
# BTCUSDT-aggTrades-2023-08-21.csv, shape : (417665, 8) res_df shape: (11609533, 8)
# BTCUSDT-aggTrades-2023-08-22.csv, shape : (446720, 8) res_df shape: (12056253, 8)
# BTCUSDT-aggTrades-2023-08-23.csv, shape : (485195, 8) res_df shape: (12541448, 8)
# BTCUSDT-aggTrades-2023-08-24.csv, shape : (433411, 8) res_df shape: (12974859, 8)
# BTCUSDT-aggTrades-2023-08-25.csv, shape : (444973, 8) res_df shape: (13419832, 8)
# BTCUSDT-aggTrades-2023-08-26.csv, shape : (255436, 8) res_df shape: (13675268, 8)
# BTCUSDT-aggTrades-2023-08-27.csv, shape : (266112, 8) res_df shape: (13941380, 8)
# BTCUSDT-aggTrades-2023-08-28.csv, shape : (384070, 8) res_df shape: (14325450, 8)
# BTCUSDT-aggTrades-2023-08-29.csv, shape : (836132, 8) res_df shape: (15161582, 8)
# BTCUSDT-aggTrades-2023-08-30.csv, shape : (525805, 8) res_df shape: (15687387, 8)
# BTCUSDT-aggTrades-2023-08-31.csv, shape : (687168, 8) res_df shape: (16374555, 8)
# BTCUSDT-aggTrades-2023-09-01.csv, shape : (655281, 8) res_df shape: (17029836, 8)
# BTCUSDT-aggTrades-2023-09-02.csv, shape : (432618, 8) res_df shape: (17462454, 8)
# BTCUSDT-aggTrades-2023-09-03.csv, shape : (388294, 8) res_df shape: (17850748, 8)
# BTCUSDT-aggTrades-2023-09-04.csv, shape : (458678, 8) res_df shape: (18309426, 8)
# BTCUSDT-aggTrades-2023-09-05.csv, shape : (433969, 8) res_df shape: (18743395, 8)
# BTCUSDT-aggTrades-2023-09-06.csv, shape : (454477, 8) res_df shape: (19197872, 8)
# BTCUSDT-aggTrades-2023-09-07.csv, shape : (447458, 8) res_df shape: (19645330, 8)
# BTCUSDT-aggTrades-2023-09-08.csv, shape : (481913, 8) res_df shape: (20127243, 8)
# BTCUSDT-aggTrades-2023-09-09.csv, shape : (300291, 8) res_df shape: (20427534, 8)
# BTCUSDT-aggTrades-2023-09-10.csv, shape : (386307, 8) res_df shape: (20813841, 8)
# BTCUSDT-aggTrades-2023-09-11.csv, shape : (634122, 8) res_df shape: (21447963, 8)
# BTCUSDT-aggTrades-2023-09-12.csv, shape : (743870, 8) res_df shape: (22191833, 8)
# BTCUSDT-aggTrades-2023-09-13.csv, shape : (519039, 8) res_df shape: (22710872, 8)
# BTCUSDT-aggTrades-2023-09-14.csv, shape : (577245, 8) res_df shape: (23288117, 8)
# BTCUSDT-aggTrades-2023-09-15.csv, shape : (493232, 8) res_df shape: (23781349, 8)
# BTCUSDT-aggTrades-2023-09-16.csv, shape : (422474, 8) res_df shape: (24203823, 8)
# BTCUSDT-aggTrades-2023-09-17.csv, shape : (387444, 8) res_df shape: (24591267, 8)
# BTCUSDT-aggTrades-2023-09-18.csv, shape : (684928, 8) res_df shape: (25276195, 8)
# BTCUSDT-aggTrades-2023-09-19.csv, shape : (667636, 8) res_df shape: (25943831, 8)
# BTCUSDT-aggTrades-2023-09-20.csv, shape : (651898, 8) res_df shape: (26595729, 8)
# BTCUSDT-aggTrades-2023-09-21.csv, shape : (626258, 8) res_df shape: (27221987, 8)
# BTCUSDT-aggTrades-2023-09-22.csv, shape : (443614, 8) res_df shape: (27665601, 8)
# BTCUSDT-aggTrades-2023-09-23.csv, shape : (352622, 8) res_df shape: (28018223, 8)
# BTCUSDT-aggTrades-2023-09-24.csv, shape : (434775, 8) res_df shape: (28452998, 8)
# BTCUSDT-aggTrades-2023-09-25.csv, shape : (669395, 8) res_df shape: (29122393, 8)
# BTCUSDT-aggTrades-2023-09-26.csv, shape : (544135, 8) res_df shape: (29666528, 8)
# BTCUSDT-aggTrades-2023-09-27.csv, shape : (710917, 8) res_df shape: (30377445, 8)
# BTCUSDT-aggTrades-2023-09-28.csv, shape : (888946, 8) res_df shape: (31266391, 8)

# %%
at_df.to_pickle(os.path.join(data_store_dir, "BTCUSDT-230729_230928", "aggtrades.pkl"))

# %%
del at_df

# %%
tr_df = df_transform(trades_path)
# Out:
# BTCUSDT-trades-2023-07-29.csv, shape : (339750, 7) res_df shape: (339750, 7)
# BTCUSDT-trades-2023-07-30.csv, shape : (454846, 7) res_df shape: (794596, 7)
# BTCUSDT-trades-2023-07-31.csv, shape : (563115, 7) res_df shape: (1357711, 7)
# BTCUSDT-trades-2023-08-01.csv, shape : (900141, 7) res_df shape: (2257852, 7)
# BTCUSDT-trades-2023-08-02.csv, shape : (945158, 7) res_df shape: (3203010, 7)
# BTCUSDT-trades-2023-08-03.csv, shape : (651970, 7) res_df shape: (3854980, 7)
# BTCUSDT-trades-2023-08-04.csv, shape : (544850, 7) res_df shape: (4399830, 7)
# BTCUSDT-trades-2023-08-05.csv, shape : (331924, 7) res_df shape: (4731754, 7)
# BTCUSDT-trades-2023-08-06.csv, shape : (338654, 7) res_df shape: (5070408, 7)
# BTCUSDT-trades-2023-08-07.csv, shape : (671438, 7) res_df shape: (5741846, 7)
# BTCUSDT-trades-2023-08-08.csv, shape : (877168, 7) res_df shape: (6619014, 7)
# BTCUSDT-trades-2023-08-09.csv, shape : (750252, 7) res_df shape: (7369266, 7)
# BTCUSDT-trades-2023-08-10.csv, shape : (513691, 7) res_df shape: (7882957, 7)
# BTCUSDT-trades-2023-08-11.csv, shape : (437828, 7) res_df shape: (8320785, 7)
# BTCUSDT-trades-2023-08-12.csv, shape : (310852, 7) res_df shape: (8631637, 7)
# BTCUSDT-trades-2023-08-13.csv, shape : (341726, 7) res_df shape: (8973363, 7)
# BTCUSDT-trades-2023-08-14.csv, shape : (671592, 7) res_df shape: (9644955, 7)
# BTCUSDT-trades-2023-08-15.csv, shape : (591162, 7) res_df shape: (10236117, 7)
# BTCUSDT-trades-2023-08-16.csv, shape : (768028, 7) res_df shape: (11004145, 7)
# BTCUSDT-trades-2023-08-17.csv, shape : (1976577, 7) res_df shape: (12980722, 7)
# BTCUSDT-trades-2023-08-18.csv, shape : (1293122, 7) res_df shape: (14273844, 7)
# BTCUSDT-trades-2023-08-19.csv, shape : (615764, 7) res_df shape: (14889608, 7)
# BTCUSDT-trades-2023-08-20.csv, shape : (451543, 7) res_df shape: (15341151, 7)
# BTCUSDT-trades-2023-08-21.csv, shape : (565987, 7) res_df shape: (15907138, 7)
# BTCUSDT-trades-2023-08-22.csv, shape : (603624, 7) res_df shape: (16510762, 7)
# BTCUSDT-trades-2023-08-23.csv, shape : (673711, 7) res_df shape: (17184473, 7)
# BTCUSDT-trades-2023-08-24.csv, shape : (575619, 7) res_df shape: (17760092, 7)
# BTCUSDT-trades-2023-08-25.csv, shape : (611438, 7) res_df shape: (18371530, 7)
# BTCUSDT-trades-2023-08-26.csv, shape : (329412, 7) res_df shape: (18700942, 7)
# BTCUSDT-trades-2023-08-27.csv, shape : (349090, 7) res_df shape: (19050032, 7)
# BTCUSDT-trades-2023-08-28.csv, shape : (523057, 7) res_df shape: (19573089, 7)
# BTCUSDT-trades-2023-08-29.csv, shape : (1137083, 7) res_df shape: (20710172, 7)
# BTCUSDT-trades-2023-08-30.csv, shape : (690292, 7) res_df shape: (21400464, 7)
# BTCUSDT-trades-2023-08-31.csv, shape : (944690, 7) res_df shape: (22345154, 7)
# BTCUSDT-trades-2023-09-01.csv, shape : (881179, 7) res_df shape: (23226333, 7)
# BTCUSDT-trades-2023-09-02.csv, shape : (567728, 7) res_df shape: (23794061, 7)
# BTCUSDT-trades-2023-09-03.csv, shape : (496412, 7) res_df shape: (24290473, 7)
# BTCUSDT-trades-2023-09-04.csv, shape : (596830, 7) res_df shape: (24887303, 7)
# BTCUSDT-trades-2023-09-05.csv, shape : (566736, 7) res_df shape: (25454039, 7)
# BTCUSDT-trades-2023-09-06.csv, shape : (636302, 7) res_df shape: (26090341, 7)
# BTCUSDT-trades-2023-09-07.csv, shape : (631929, 7) res_df shape: (26722270, 7)
# BTCUSDT-trades-2023-09-08.csv, shape : (646852, 7) res_df shape: (27369122, 7)
# BTCUSDT-trades-2023-09-09.csv, shape : (359038, 7) res_df shape: (27728160, 7)
# BTCUSDT-trades-2023-09-10.csv, shape : (489773, 7) res_df shape: (28217933, 7)
# BTCUSDT-trades-2023-09-11.csv, shape : (864138, 7) res_df shape: (29082071, 7)
# BTCUSDT-trades-2023-09-12.csv, shape : (1047056, 7) res_df shape: (30129127, 7)
# BTCUSDT-trades-2023-09-13.csv, shape : (714880, 7) res_df shape: (30844007, 7)
# BTCUSDT-trades-2023-09-14.csv, shape : (799278, 7) res_df shape: (31643285, 7)
# BTCUSDT-trades-2023-09-15.csv, shape : (654094, 7) res_df shape: (32297379, 7)
# BTCUSDT-trades-2023-09-16.csv, shape : (526416, 7) res_df shape: (32823795, 7)
# BTCUSDT-trades-2023-09-17.csv, shape : (476775, 7) res_df shape: (33300570, 7)
# BTCUSDT-trades-2023-09-18.csv, shape : (938705, 7) res_df shape: (34239275, 7)
# BTCUSDT-trades-2023-09-19.csv, shape : (898076, 7) res_df shape: (35137351, 7)
# BTCUSDT-trades-2023-09-20.csv, shape : (867288, 7) res_df shape: (36004639, 7)
# BTCUSDT-trades-2023-09-21.csv, shape : (823416, 7) res_df shape: (36828055, 7)
# BTCUSDT-trades-2023-09-22.csv, shape : (567149, 7) res_df shape: (37395204, 7)
# BTCUSDT-trades-2023-09-23.csv, shape : (421717, 7) res_df shape: (37816921, 7)
# BTCUSDT-trades-2023-09-24.csv, shape : (545045, 7) res_df shape: (38361966, 7)
# BTCUSDT-trades-2023-09-25.csv, shape : (873488, 7) res_df shape: (39235454, 7)
# BTCUSDT-trades-2023-09-26.csv, shape : (697727, 7) res_df shape: (39933181, 7)
# BTCUSDT-trades-2023-09-27.csv, shape : (939690, 7) res_df shape: (40872871, 7)
# BTCUSDT-trades-2023-09-28.csv, shape : (1158974, 7) res_df shape: (42031845, 7)

# %%
tr_df.to_pickle(os.path.join(data_store_dir, "BTCUSDT-230729_230928", "trades.pkl"))
